# %% [markdown]
# <a href="https://colab.research.google.com/github/ksreddy543/DSA/blob/main/Heaps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import heapq

A = [1,2,5,0,3,8,-2]

heapq.heapify(A)

A

heapq.heap
# Out:
# [-2, 0, 1, 2, 3, 8, 5]
